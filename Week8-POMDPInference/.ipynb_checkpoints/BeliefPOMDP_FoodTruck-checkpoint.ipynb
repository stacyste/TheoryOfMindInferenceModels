# %%
import itertools
import numpy as np

# %%
import sys
sys.path.append('../')
from SetupTransitionTable import SetupDeterministicTransitionByStateSet
from SetupRewardTable import SetupStateActionRewardTableWithDistanceMoveCost
from visualizations import *

# %% [markdown]
# # Environments

# %% [markdown]
# Three possible environments: C, Reverse C, and O shaped (letter corresponds to where the barrier is)
#
# environmentC, environmentReverseC, and environmentO are the environmental dynamics for each environment.

# %%
# Actions correspond to E, N, W, S, Stay respectively
allActions = [(1,0), (0,1), (-1,0), (0,-1), (0,0)]

#all location states in grid
gridWidth = 10
gridHeight = 5
gridSet = set(itertools.product(range(gridWidth), range(gridHeight)))

#set of states to remove from each environment
barriersC = {(2,2), (3,2), (4,2), (5,2), (6,2), (7,2), (8,2), (9,2)}
barriersReverseC = {(0,2), (1,2), (2,2), (3,2), (4,2), (5,2), (6,2), (7,2)}
barriersO = {(2,2), (3,2), (4,2), (5,2), (6,2), (7,2)}

#final environment state sets
stateSetC = list(gridSet.difference(barriersC))
stateSetReverseC = list(gridSet.difference(barriersReverseC))
stateSetO = list(gridSet.difference(barriersO))

#goal locations
goal1 = (0,0)
goal2 = (9,4)

#probability of ineffective action
#epsilon = .1

# %%
getTransitionC = SetupDeterministicTransitionByStateSet(stateSetC, allActions)
getTransitionReverseC = SetupDeterministicTransitionByStateSet(stateSetReverseC, allActions)
getTransitionO = SetupDeterministicTransitionByStateSet(stateSetO, allActions)

# possible environment transitions
environmentC = getTransitionC()
environmentReverseC = getTransitionReverseC()
environmentO = getTransitionO()

# %%
"""
Probabilistically draw the next location state given the dynamics of the transition function
Input: transition dictionary, current state tuple, action tuple
Output: next location state tuple
"""
def drawNextState(transitionFunction, state, action):
    nextStates = list(transitionFunction[state][action].keys())
    probabilities = list(transitionFunction[state][action].values())
    nextState = nextStates[np.random.choice(len(nextStates), p=probabilities)]
    return(nextState)

# %%
# Example:
drawNextState(environmentC, (0,0), (1,0))
# Out:
# (1, 0)

# %% [markdown]
# ## Environment C Example

# %%
viewDictionaryStructure(environmentC, "t")
# Out:
# state: (7, 3)
# 	action: (1, 0)
# 		next state: (8, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (7, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (6, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (7, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (7, 3)
# 			probability: 1
# state: (1, 3)
# 	action: (1, 0)
# 		next state: (2, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (1, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (1, 2)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (1, 3)
# 			probability: 1
# state: (9, 1)
# 	action: (1, 0)
# 		next state: (9, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (9, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (8, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (9, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (9, 1)
# 			probability: 1
# state: (3, 0)
# 	action: (1, 0)
# 		next state: (4, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (3, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (2, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (3, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (3, 0)
# 			probability: 1
# state: (0, 2)
# 	action: (1, 0)
# 		next state: (1, 2)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (0, 3)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 2)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (0, 1)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (0, 2)
# 			probability: 1
# state: (8, 0)
# 	action: (1, 0)
# 		next state: (9, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (8, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (7, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (8, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (8, 0)
# 			probability: 1
# state: (2, 1)
# 	action: (1, 0)
# 		next state: (3, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (2, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (1, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (2, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (2, 1)
# 			probability: 1
# state: (9, 4)
# 	action: (1, 0)
# 		next state: (9, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (9, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (8, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (9, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (9, 4)
# 			probability: 1
# state: (5, 1)
# 	action: (1, 0)
# 		next state: (6, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (5, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (4, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (5, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (5, 1)
# 			probability: 1
# state: (0, 3)
# 	action: (1, 0)
# 		next state: (1, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (0, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (0, 2)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (0, 3)
# 			probability: 1
# state: (4, 0)
# 	action: (1, 0)
# 		next state: (5, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (4, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (3, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (4, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (4, 0)
# 			probability: 1
# state: (1, 2)
# 	action: (1, 0)
# 		next state: (1, 2)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (1, 3)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 2)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (1, 1)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (1, 2)
# 			probability: 1
# state: (9, 0)
# 	action: (1, 0)
# 		next state: (9, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (9, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (8, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (9, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (9, 0)
# 			probability: 1
# state: (3, 3)
# 	action: (1, 0)
# 		next state: (4, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (3, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (2, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (3, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (3, 3)
# 			probability: 1
# state: (8, 1)
# 	action: (1, 0)
# 		next state: (9, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (8, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (7, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (8, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (8, 1)
# 			probability: 1
# state: (4, 4)
# 	action: (1, 0)
# 		next state: (5, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (4, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (3, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (4, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (4, 4)
# 			probability: 1
# state: (6, 3)
# 	action: (1, 0)
# 		next state: (7, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (6, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (5, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (6, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (6, 3)
# 			probability: 1
# state: (5, 0)
# 	action: (1, 0)
# 		next state: (6, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (5, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (4, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (5, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (5, 0)
# 			probability: 1
# state: (0, 4)
# 	action: (1, 0)
# 		next state: (1, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (0, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (0, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (0, 4)
# 			probability: 1
# state: (4, 1)
# 	action: (1, 0)
# 		next state: (5, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (4, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (3, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (4, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (4, 1)
# 			probability: 1
# state: (1, 1)
# 	action: (1, 0)
# 		next state: (2, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (1, 2)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (1, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (1, 1)
# 			probability: 1
# state: (6, 4)
# 	action: (1, 0)
# 		next state: (7, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (6, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (5, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (6, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (6, 4)
# 			probability: 1
# state: (0, 0)
# 	action: (1, 0)
# 		next state: (1, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (0, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (0, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (0, 0)
# 			probability: 1
# state: (5, 4)
# 	action: (1, 0)
# 		next state: (6, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (5, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (4, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (5, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (5, 4)
# 			probability: 1
# state: (7, 1)
# 	action: (1, 0)
# 		next state: (8, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (7, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (6, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (7, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (7, 1)
# 			probability: 1
# state: (9, 3)
# 	action: (1, 0)
# 		next state: (9, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (9, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (8, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (9, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (9, 3)
# 			probability: 1
# state: (6, 0)
# 	action: (1, 0)
# 		next state: (7, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (6, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (5, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (6, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (6, 0)
# 			probability: 1
# state: (1, 4)
# 	action: (1, 0)
# 		next state: (2, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (1, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (1, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (1, 4)
# 			probability: 1
# state: (2, 3)
# 	action: (1, 0)
# 		next state: (3, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (2, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (1, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (2, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (2, 3)
# 			probability: 1
# state: (1, 0)
# 	action: (1, 0)
# 		next state: (2, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (1, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (1, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (1, 0)
# 			probability: 1
# state: (5, 3)
# 	action: (1, 0)
# 		next state: (6, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (5, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (4, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (5, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (5, 3)
# 			probability: 1
# state: (0, 1)
# 	action: (1, 0)
# 		next state: (1, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (0, 2)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (0, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (0, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (0, 1)
# 			probability: 1
# state: (8, 3)
# 	action: (1, 0)
# 		next state: (9, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (8, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (7, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (8, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (8, 3)
# 			probability: 1
# state: (7, 0)
# 	action: (1, 0)
# 		next state: (8, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (7, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (6, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (7, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (7, 0)
# 			probability: 1
# state: (6, 1)
# 	action: (1, 0)
# 		next state: (7, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (6, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (5, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (6, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (6, 1)
# 			probability: 1
# state: (3, 1)
# 	action: (1, 0)
# 		next state: (4, 1)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (3, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (2, 1)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (3, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (3, 1)
# 			probability: 1
# state: (7, 4)
# 	action: (1, 0)
# 		next state: (8, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (7, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (6, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (7, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (7, 4)
# 			probability: 1
# state: (2, 0)
# 	action: (1, 0)
# 		next state: (3, 0)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (2, 1)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (1, 0)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (2, 0)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (2, 0)
# 			probability: 1
# state: (4, 3)
# 	action: (1, 0)
# 		next state: (5, 3)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (4, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (3, 3)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (4, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (4, 3)
# 			probability: 1
# state: (3, 4)
# 	action: (1, 0)
# 		next state: (4, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (3, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (2, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (3, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (3, 4)
# 			probability: 1
# state: (2, 4)
# 	action: (1, 0)
# 		next state: (3, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (2, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (1, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (2, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (2, 4)
# 			probability: 1
# state: (8, 4)
# 	action: (1, 0)
# 		next state: (9, 4)
# 			probability: 1
# 	action: (0, 1)
# 		next state: (8, 4)
# 			probability: 1
# 	action: (-1, 0)
# 		next state: (7, 4)
# 			probability: 1
# 	action: (0, -1)
# 		next state: (8, 3)
# 			probability: 1
# 	action: (0, 0)
# 		next state: (8, 4)
# 			probability: 1

# %%
visualizeEnvironmentByState(states = stateSetC, goalStates = [(0,0), (9,4)], trajectory = [(7,1)])

# %% [markdown]
# # Preferences

# %% [markdown]
# lists all possible worlds as well as all possible preference rankings among K, L, and M

# %%
allWorlds = [(c1, c2) for c1, c2 in itertools.permutations("KLM", 2)]
possibleWorldsInLocation = [{goal1: comb1, goal2: comb2} for comb1, comb2 in itertools.permutations("KLM", 2)]
possiblePreferenceRankings = [rank for rank in itertools.permutations("KLM",3)]

# %%
print(allWorlds, "\n")
print(possibleWorldsInLocation, "\n")
print(possiblePreferenceRankings, "\n")
# Out:
# [('K', 'L'), ('K', 'M'), ('L', 'K'), ('L', 'M'), ('M', 'K'), ('M', 'L')]
#
# [{(0, 0): 'K', (9, 4): 'L'}, {(0, 0): 'K', (9, 4): 'M'}, {(0, 0): 'L', (9, 4): 'K'}, {(0, 0): 'L', (9, 4): 'M'}, {(0, 0): 'M', (9, 4): 'K'}, {(0, 0): 'M', (9, 4): 'L'}]
#
# [('K', 'L', 'M'), ('K', 'M', 'L'), ('L', 'K', 'M'), ('L', 'M', 'K'), ('M', 'K', 'L'), ('M', 'L', 'K')]

# %%
"""
Construct the input for a reward function.

Inputs: world is a dictionary where keys are the coordinates of goals and the values are the names of those goals
preference is a tuple indicating the relatve ranking of the worth of goals and 
preference rewards is a list of how much reward the rank of each goal should receive

outputs: a dictionary with goal locations as keys and the numerical reward associated with them as the values
"""
def constructPreferences(world, preference, preferenceRewards = [1000, 400, 100]):
    goalPreferences = {location : preferenceRewards[preference.index(truck)] for location, truck in world.items()}
    return(goalPreferences)

# %%
#Example
print(constructPreferences({(0,0):'L', (9,4):'K'}, ('M', 'L', 'K')))
print(constructPreferences(possibleWorldsInLocation[2], possiblePreferenceRankings[-1]))
# Out:
# {(0, 0): 400, (9, 4): 100}
# {(0, 0): 400, (9, 4): 100}

# %% [markdown]
# # Rewards R(s, a, s')

# %% [markdown]
# Reward is defined for first, the environment, and second for the relative preferences of the agent.
# We create a reward for each possible world, given that preference relation.

# %%
getRewardC = SetupStateActionRewardTableWithDistanceMoveCost(environmentC, allActions)

# %%
# example preference of M > K > L, a true world of K in position 0,0 and L in position 9,4
klWorld_mlkPreference = constructPreferences(possibleWorldsInLocation[2], possiblePreferenceRankings[-1])

# example reward function dictionaries for environment C dynamics, Preference M > K > L 
rewards_EnvC_PrefMLK = {tuple(world.values()) : getRewardC(constructPreferences(world, possiblePreferenceRankings[-1])) \
                        for world in possibleWorldsInLocation}

# %%
viewDictionaryStructure(rewards_EnvC_PrefMLK[('L', 'K')], 'r')
# Out:
# state: (7, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (1, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (9, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (3, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (0, 2)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (8, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (2, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (9, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (5, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (0, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (4, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (1, 2)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (9, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (3, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (8, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (4, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (6, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (5, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (0, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (4, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (1, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (6, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (0, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (5, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (7, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (9, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (6, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (1, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (2, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (1, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (5, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (0, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (8, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (7, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (6, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (3, 1)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (7, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (2, 0)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (4, 3)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (3, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (2, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1
# state: (8, 4)
# 	action: (1, 0)
# 		next state: -1
# 	action: (0, 1)
# 		next state: -1
# 	action: (-1, 0)
# 		next state: -1
# 	action: (0, -1)
# 		next state: -1
# 	action: (0, 0)
# 		next state: -0.1

# %% [markdown]
# # Belief Rewards Rho(b, s, a, s')

# %%
def getBeliefReward(worldBeliefs, worldRewardFunctions, state, action, nextState):
    beliefReward = sum([worldBeliefs[y]*worldRewardFunctions[y][state][action][nextState] for y in worldBeliefs])
    return(beliefReward)

# %%
# Example
impartial_b = {world: 1/6 for world in itertools.permutations("KLM", 2)}

# %%
getBeliefReward(impartial_b, rewards_EnvC_PrefMLK, (0,0), (0,0), (0,0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6b5de75c29c3> in <module>()
# ----> 1 getBeliefReward(impartial_b, rewards_EnvC_PrefMLK, (0,0), (0,0), (0,0))
#
# <ipython-input-16-c72189ebe0a1> in getBeliefReward(worldBeliefs, worldRewardFunctions, state, action, nextState)
#       1 def getBeliefReward(worldBeliefs, worldRewardFunctions, state, action, nextState):
# ----> 2     beliefReward = sum([worldBeliefs[y]*worldRewardFunctions[y][state][action][nextState] for y in worldBeliefs])
#       3     return(beliefReward)
#
# <ipython-input-16-c72189ebe0a1> in <listcomp>(.0)
#       1 def getBeliefReward(worldBeliefs, worldRewardFunctions, state, action, nextState):
# ----> 2     beliefReward = sum([worldBeliefs[y]*worldRewardFunctions[y][state][action][nextState] for y in worldBeliefs])
#       3     return(beliefReward)
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# # Belief Updating: Tau(b, a, b')

# %% [markdown]
# $$ b_t(y) \propto p(o_t|x_t, y, env)b_{t-1}(y)$$

# %% [markdown]
# ## constructing P(o|x, y)

# %%
def createObservations(environment, trueWorldInLocation, stateSet):
    #{world : position state : possible goal: indicator of whether that possible goal is visible in that state/world combo}
